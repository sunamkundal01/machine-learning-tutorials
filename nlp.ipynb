# %% [markdown]
# <a href="https://colab.research.google.com/github/sunamkundal01/pytorch-tutorials/blob/main/nlp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import string
url='https://raw.githubusercontent.com/sharmaroshan/Twitter-Sentiment-Analysis/refs/heads/master/test_tweets.csv'
df=pd.read_csv(url)
df=df.drop(['id'],axis=1)
df.head()
# Out:
#                                                tweet
# 0  #studiolife #aislife #requires #passion #dedic...
# 1   @user #white #supremacists want everyone to s...
# 2  safe ways to heal your #acne!!    #altwaystohe...
# 3  is the hp and the cursed child book up for res...
# 4    3rd #bihday to my amazing, hilarious #nephew...

# %%
#convert to lowewr case
df['clean_tweet']=df['tweet'].str.lower()
df.head()
# Out:
#                                                tweet  \
# 0  #studiolife #aislife #requires #passion #dedic...
# 1   @user #white #supremacists want everyone to s...
# 2  safe ways to heal your #acne!!    #altwaystohe...
# 3  is the hp and the cursed child book up for res...
# 4    3rd #bihday to my amazing, hilarious #nephew...
#
#                                          clean_tweet
# 0  #studiolife #aislife #requires #passion #dedic...
# 1   @user #white #supremacists want everyone to s...
# 2  safe ways to heal your #acne!!    #altwaystohe...
# 3  is the hp and the cursed child book up for res...
# 4    3rd #bihday to my amazing, hilarious #nephew...

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
#removal of puncuations
def remove_puncuation(text):

    translator=str.maketrans('','',string.punctuation)
    return text.translate(translator)

# %%
df['clean_tweet']=df['clean_tweet'].apply(lambda x:remove_puncuation(x))
df.head()
# Out:
#                                                tweet  \
# 0  #studiolife #aislife #requires #passion #dedic...
# 1   @user #white #supremacists want everyone to s...
# 2  safe ways to heal your #acne!!    #altwaystohe...
# 3  is the hp and the cursed child book up for res...
# 4    3rd #bihday to my amazing, hilarious #nephew...
#
#                                          clean_tweet
# 0  studiolife aislife requires passion dedication...
# 1   user white supremacists want everyone to see ...
# 2  safe ways to heal your acne    altwaystoheal h...
# 3  is the hp and the cursed child book up for res...
# 4    3rd bihday to my amazing hilarious nephew el...

# %%
#removal of stopwords
import nltk
nltk.download('stopwords')

from nltk.corpus import stopwords
stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
# ...

# %%
",".join(stopwords.words('english'))
# Out:
# "i,me,my,myself,we,our,ours,ourselves,you,you're,you've,you'll,you'd,your,yours,yourself,yourselves,he,him,his,himself,she,she's,her,hers,herself,it,it's,its,itself,they,them,their,theirs,themselves,what,which,who,whom,this,that,that'll,these,those,am,is,are,was,were,be,been,being,have,has,had,having,do,does,did,doing,a,an,the,and,but,if,or,because,as,until,while,of,at,by,for,with,about,against,between,into,through,during,before,after,above,below,to,from,up,down,in,out,on,off,over,under,again,further,then,once,here,there,when,where,why,how,all,any,both,each,few,more,most,other,some,such,no,nor,not,only,own,same,so,than,too,very,s,t,can,will,just,don,don't,should,should've,now,d,ll,m,o,re,ve,y,ain,aren,aren't,couldn,couldn't,didn,didn't,doesn,doesn't,hadn,hadn't,hasn,hasn't,haven,haven't,isn,isn't,ma,mightn,mightn't,mustn,mustn't,needn,needn't,shan,shan't,shouldn,shouldn't,wasn,wasn't,weren,weren't,won,won't,wouldn,wouldn't"

# %%
stopwords=set(stopwords.words('english'))

# %%
def remove_stopwords(text):
    text=[word for word in text.split() if word not in stopwords]
    return " ".join(text)

# %%
df['clean_tweet']=df['clean_tweet'].apply(lambda x:remove_stopwords(x))
df.head()
# Out:
#                                                tweet  \
# 0  #studiolife #aislife #requires #passion #dedic...
# 1   @user #white #supremacists want everyone to s...
# 2  safe ways to heal your #acne!!    #altwaystohe...
# 3  is the hp and the cursed child book up for res...
# 4    3rd #bihday to my amazing, hilarious #nephew...
#
#                                          clean_tweet
# 0  studiolife aislife requires passion dedication...
# 1  user white supremacists want everyone see new ...
# 2  safe ways heal acne altwaystoheal healthy healing
# 3  hp cursed child book reservations already yes ...
# 4  3rd bihday amazing hilarious nephew eli ahmir ...

# %%
## removal of frequent words
from collections import Counter
cnt=Counter()
for text in df['clean_tweet'].values:
    for word in text.split():
        cnt[word]+=1

cnt.most_common(10)
# Out:
# [('user', 9503),
#  ('love', 1452),
#  ('day', 1120),
#  ('happy', 921),
#  ('amp', 804),
#  ('u', 623),
#  ('time', 611),
#  ('im', 601),
#  ('life', 579),
#  ('new', 556)]

# %%
 # remove top words -3
remove_words=set(w for (w,wc) in cnt.most_common(3))
def remove_top_words(text):
    text=[word for word in text.split() if word not in remove_words]
    return " ".join(text)

# %%
df['clean_tweet']=df['clean_tweet'].apply(lambda x:remove_top_words(x))
df.head()
# Out:
#                                                tweet  \
# 0  #studiolife #aislife #requires #passion #dedic...
# 1   @user #white #supremacists want everyone to s...
# 2  safe ways to heal your #acne!!    #altwaystohe...
# 3  is the hp and the cursed child book up for res...
# 4    3rd #bihday to my amazing, hilarious #nephew...
#
#                                          clean_tweet
# 0  studiolife aislife requires passion dedication...
# 1  white supremacists want everyone see new â b...
# 2  safe ways heal acne altwaystoheal healthy healing
# 3  hp cursed child book reservations already yes ...
# 4  3rd bihday amazing hilarious nephew eli ahmir ...

# %%
### Removal of rare words
rare_words=set(w for (w,wc) in cnt.most_common()[:-10:-1])
rare_words
# Out:
# {'2damntuffruffmufftechnocityng005web1997ukhxint',
#  'assetsampliability',
#  'campaigned',
#  'hairflip',
#  'neverready',
#  'ohioomg',
#  'radicalization',
#  'shoegaze',
#  'theeword'}

# %%
def remove_rare_words(text):
    text=[word for word in text.split() if word not in rare_words]
    return " ".join(text)

# %%
df['clean_tweet']=df['clean_tweet'].apply(lambda x:remove_rare_words(x))
df.head()
# Out:
#                                                tweet  \
# 0  #studiolife #aislife #requires #passion #dedic...
# 1   @user #white #supremacists want everyone to s...
# 2  safe ways to heal your #acne!!    #altwaystohe...
# 3  is the hp and the cursed child book up for res...
# 4    3rd #bihday to my amazing, hilarious #nephew...
#
#                                          clean_tweet
# 0  studiolife aislife requires passion dedication...
# 1  white supremacists want everyone see new â b...
# 2  safe ways heal acne altwaystoheal healthy healing
# 3  hp cursed child book reservations already yes ...
# 4  3rd bihday amazing hilarious nephew eli ahmir ...

# %%
##removal of special chars
import re
def remove_special_chars(text):
    text=re.sub('[^a-zA-Z0-9\s]','',text)
    return text

# %%
df['clean_tweet']=df['clean_tweet'].apply(lambda x:remove_special_chars(x))
df.head()
# Out:
#                                                tweet  \
# 0  #studiolife #aislife #requires #passion #dedic...
# 1   @user #white #supremacists want everyone to s...
# 2  safe ways to heal your #acne!!    #altwaystohe...
# 3  is the hp and the cursed child book up for res...
# 4    3rd #bihday to my amazing, hilarious #nephew...
#
#                                          clean_tweet
# 0  studiolife aislife requires passion dedication...
# 1  white supremacists want everyone see new  bird...
# 2  safe ways heal acne altwaystoheal healthy healing
# 3  hp cursed child book reservations already yes ...
# 4  3rd bihday amazing hilarious nephew eli ahmir ...

# %%
## stemming
from nltk.stem import PorterStemmer
st=PorterStemmer()
def stemming(text):
    text=' '.join([st.stem(word) for word in text.split()])
    return text

# %%
## creating new col
df['stemmed_tweet']=df['clean_tweet'].apply(lambda x:stemming(x))
df.head()
# Out:
#                                                tweet  \
# 0  #studiolife #aislife #requires #passion #dedic...
# 1   @user #white #supremacists want everyone to s...
# 2  safe ways to heal your #acne!!    #altwaystohe...
# 3  is the hp and the cursed child book up for res...
# 4    3rd #bihday to my amazing, hilarious #nephew...
#
#                                          clean_tweet  \
# 0  studiolife aislife requires passion dedication...
# 1  white supremacists want everyone see new  bird...
# 2  safe ways heal acne altwaystoheal healthy healing
# 3  hp cursed child book reservations already yes ...
# 4  3rd bihday amazing hilarious nephew eli ahmir ...
#
#                                        stemmed_tweet
# 0  studiolif aislif requir passion dedic willpow ...
# 1  white supremacist want everyon see new bird mo...
# 2          safe way heal acn altwaystoh healthi heal
# 3  hp curs child book reserv alreadi ye harrypott...
# 4  3rd bihday amaz hilari nephew eli ahmir uncl d...

# %%
## Lemmatization & POS Tagging
import nltk
nltk.download('averaged_perceptron_tagger')

from nltk import pos_tag

from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
nltk.download('wordnet')
lemmatizer=WordNetLemmatizer()
wordnet_map={'N':wordnet.NOUN,'V':wordnet.VERB,'J':wordnet.ADJ,'R':wordnet.ADV}
def lemmatize_words(text):
  #find pos tags
    pos_tagged_text=pos_tag(text.split())
    return ' '.join([lemmatizer.lemmatize(word,wordnet_map.get(pos[0],wordnet.NOUN)) for word,pos in pos_tagged_text])
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df['lemmatized_tweet']=df['clean_tweet'].apply(lambda x:lemmatize_words(x))
df.head()
# Out:
#                                                tweet  \
# 0  #studiolife #aislife #requires #passion #dedic...
# 1   @user #white #supremacists want everyone to s...
# 2  safe ways to heal your #acne!!    #altwaystohe...
# 3  is the hp and the cursed child book up for res...
# 4    3rd #bihday to my amazing, hilarious #nephew...
#
#                                          clean_tweet  \
# 0  studiolife aislife requires passion dedication...
# 1  white supremacists want everyone see new  bird...
# 2  safe ways heal acne altwaystoheal healthy healing
# 3  hp cursed child book reservations already yes ...
# 4  3rd bihday amazing hilarious nephew eli ahmir ...
#
#                                        stemmed_tweet  \
# 0  studiolif aislif requir passion dedic willpow ...
# 1  white supremacist want everyon see new bird mo...
# 2          safe way heal acn altwaystoh healthi heal
# 3  hp curs child book reserv alreadi ye harrypott...
# ...

# %%
df.sample(frac=1).head(10)
# Out:
#                                                    tweet  \
# 7816    @user you 24 finna be 25 dating a 16 year old...
# 2885    @user how am i just discovering this podcast?!
# 9125    @user .@user a number of our leaders are comi...
# 14515  @user @user if you say i am  have the balls to...
# 2151   #bruh this had me in #tears!! #funny #kungfu #...
# 11553  last day off college with my wee babe @user gu...
# 13851  from the archives, roz bellamy's moving essay ...
# 13555  white: good  dark: bad  itâs a twisted versi...
# 1513    @user countdown to the las vegas licensing ex...
# 14520            weekend with my girls is much needed
#
#                                              clean_tweet  \
# 7816   24 finna 25 dating 16 year old  need jail hous...
# 2885                                 discovering podcast
# 9125                               number leaders coming
# 14515                                  say balls hashtag
# ...

# %%
# removal of urls
text="https://www.google.com"

# %%
def remove_url(text):
  return re.sub(r"http\S+","",text)

# %%
remove_url(text)
# Out:
# ''

# %%
#spelling correction
# !pip install pyspellchecker # Install the correct package, pyspellchecker.
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 51.4 MB/s eta 0:00:00
# ...

# %%
from spellchecker import SpellChecker
text="natur is a sunam "
spell=SpellChecker()
def correct_spellings(text):
  corrected_text=[]
  misspelled_words=spell.unknown(text.split())
  # print(misspelled_words)
  for word in text.split():
    if word in misspelled_words:
      corrected_text.append(spell.correction(word))
    else:
      corrected_text.append(word)
  return " ".join(corrected_text)

# %%
correct_spellings(text)
# Out:
# 'nature is a sun'
